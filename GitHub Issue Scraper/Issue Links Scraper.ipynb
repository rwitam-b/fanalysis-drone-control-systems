# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from urllib.parse import urlencode
import time
import json

options = Options()
options.headless = True
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

# Configuration
OUTPUT_ROOT = './scrape_data'

# %% [markdown]
# ### Utility functions to scrape GitHub Issue links and px4 log links

# %%
def scrape_issue_links(url, retry):
    # Start selenium scraper    
    print(f"Starting to scrape {url}")
    driver.get(url)

    # Parse response
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    anchors = soup.find_all('a')

    # Grabbing the issue links
    urls = [f"https://github.com{a['href']}" for a in anchors if a.get('id') and "issue_" in a.get('id')]

    print(f"Found {len(anchors)} links on page and scraped {len(urls)} issues!\n")
    
    # Fix in case of throttling
    if retry and len(urls) < 5:
        print("Potential throttling detected, waiting to retry again")
        time.sleep(30)
        return scrape_issue_links(url, False)
    else:
        return urls

def scrape_px4_links(url, retry):
    # Start selenium scraper
    print(f"Starting to scrape {url}")
    driver.get(url)

    # Parse response
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    anchors = soup.find_all('a')

    # Grabbing the issue links
    urls = [a['href'] for a in anchors if "px4.io" in a.get('href')]

    print(f"Found {len(anchors)} links on page and scraped {len(urls)} px4 log links!\n")
    
    # Fix in case of throttling
    if retry and len(urls) == 0:
        print("Zero links found, waiting to retry again")
        time.sleep(30)
        return scrape_px4_links(url, False)
    else:
        return urls

# %% [markdown]
# ### Gathering GitHub issues in PX4-Autopilot which have "logs.px4.io" in content

# %%
# Manually searched with the conditions and found total page numbers
issue_page = 'https://github.com/PX4/PX4-Autopilot/issues'
issue_page_params = {
    'page': '1',
    'q': '"logs.px4.io" in:title,body,comments'
}
total_issue_pages = 43

issue_links = []
for page_number in range(1, total_issue_pages + 1):
    # Go through each page and scrape issue URLs
    issue_page_params['page'] = str(page_number)
    url = f"{issue_page}?{urlencode(issue_page_params)}"
    issue_links += scrape_issue_links(url, True)
    
# Write to file
if len(issue_links) > 0:
    with open(f"{OUTPUT_ROOT}/github_issues_(logs.px4.io).json", "w") as fp:
        json.dump(issue_links, fp)
# Out:
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=1&q=%22logs.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 261 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=2&q=%22logs.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 238 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=3&q=%22logs.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 254 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=4&q=%22logs.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 257 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=5&q=%22logs.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 258 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=6&q=%22logs.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 251 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=7&q=%22logs.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 260 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=8&q=%22logs.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 258 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=9&q=%22logs.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 261 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=10&q=%22logs.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 275 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=11&q=%22logs.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 291 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=12&q=%22logs.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 286 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=13&q=%22logs.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 302 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=14&q=%22logs.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 287 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=15&q=%22logs.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 269 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=16&q=%22logs.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 274 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=17&q=%22logs.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 292 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=18&q=%22logs.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 274 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=19&q=%22logs.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 254 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=20&q=%22logs.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 252 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=21&q=%22logs.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 266 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=22&q=%22logs.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 232 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=23&q=%22logs.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 244 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=24&q=%22logs.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 255 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=25&q=%22logs.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 258 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=26&q=%22logs.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 228 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=27&q=%22logs.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 250 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=28&q=%22logs.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 3 links on page and scraped 0 issues!
#
# Potential throttling detected, waiting to retry again
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=28&q=%22logs.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 260 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=29&q=%22logs.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 243 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=30&q=%22logs.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 259 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=31&q=%22logs.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 255 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=32&q=%22logs.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 276 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=33&q=%22logs.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 260 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=34&q=%22logs.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 271 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=35&q=%22logs.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 260 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=36&q=%22logs.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 246 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=37&q=%22logs.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 235 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=38&q=%22logs.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 263 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=39&q=%22logs.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 266 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=40&q=%22logs.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 238 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=41&q=%22logs.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 5 links on page and scraped 0 issues!
#
# Potential throttling detected, waiting to retry again
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=41&q=%22logs.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 5 links on page and scraped 0 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=42&q=%22logs.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 5 links on page and scraped 0 issues!
#
# Potential throttling detected, waiting to retry again
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=42&q=%22logs.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 99 links on page and scraped 0 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=43&q=%22logs.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 99 links on page and scraped 0 issues!
#
# Potential throttling detected, waiting to retry again
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=43&q=%22logs.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 100 links on page and scraped 0 issues!

# %% [markdown]
# ### Gathering GitHub issues in PX4-Autopilot which have "review.px4.io" in content

# %%
# Manually searched with the conditions and found total page numbers
issue_page = 'https://github.com/PX4/PX4-Autopilot/issues'
issue_page_params = {
    'page': '1',
    'q': '"review.px4.io" in:title,body,comments'
}
total_issue_pages = 43

issue_links = []
for page_number in range(1, total_issue_pages + 1):
    # Go through each page and scrape issue URLs
    issue_page_params['page'] = str(page_number)
    url = f"{issue_page}?{urlencode(issue_page_params)}"
    issue_links += scrape_issue_links(url, True)
    
# Write to file
if len(issue_links) > 0:
    with open(f"{OUTPUT_ROOT}/github_issues_(review.px4.io).json", "w") as fp:
        json.dump(issue_links, fp)
# Out:
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=1&q=%22review.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 253 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=2&q=%22review.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 253 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=3&q=%22review.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 250 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=4&q=%22review.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 231 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=5&q=%22review.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 229 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=6&q=%22review.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 241 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=7&q=%22review.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 243 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=8&q=%22review.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 250 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=9&q=%22review.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 239 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=10&q=%22review.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 233 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=11&q=%22review.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 250 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=12&q=%22review.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 255 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=13&q=%22review.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 251 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=14&q=%22review.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 279 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=15&q=%22review.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 286 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=16&q=%22review.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 306 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=17&q=%22review.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 273 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=18&q=%22review.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 285 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=19&q=%22review.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 278 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=20&q=%22review.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 277 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=21&q=%22review.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 282 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=22&q=%22review.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 3 links on page and scraped 0 issues!
#
# Potential throttling detected, waiting to retry again
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=22&q=%22review.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 271 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=23&q=%22review.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 271 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=24&q=%22review.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 282 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=25&q=%22review.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 266 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=26&q=%22review.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 261 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=27&q=%22review.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 261 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=28&q=%22review.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 279 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=29&q=%22review.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 271 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=30&q=%22review.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 280 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=31&q=%22review.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 254 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=32&q=%22review.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 274 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=33&q=%22review.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 243 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=34&q=%22review.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 248 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=35&q=%22review.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 260 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=36&q=%22review.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 275 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=37&q=%22review.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 270 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=38&q=%22review.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 5 links on page and scraped 0 issues!
#
# Potential throttling detected, waiting to retry again
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=38&q=%22review.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 264 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=39&q=%22review.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 266 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=40&q=%22review.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 254 links on page and scraped 25 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=41&q=%22review.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 100 links on page and scraped 0 issues!
#
# Potential throttling detected, waiting to retry again
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=41&q=%22review.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 99 links on page and scraped 0 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=42&q=%22review.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 99 links on page and scraped 0 issues!
#
# Potential throttling detected, waiting to retry again
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=42&q=%22review.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 100 links on page and scraped 0 issues!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=43&q=%22review.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 99 links on page and scraped 0 issues!
#
# Potential throttling detected, waiting to retry again
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues?page=43&q=%22review.px4.io%22+in%3Atitle%2Cbody%2Ccomments
# Found 100 links on page and scraped 0 issues!

# %% [markdown]
# ### Going through all the GitHub issues and scraping px4 log links if any are attached

# %%
# Configuration
ISSUE_LINKS = [f"{OUTPUT_ROOT}/github_issues_(logs.px4.io).json", f"{OUTPUT_ROOT}/github_issues_(review.px4.io).json"]

# %%
links = []
for link_file in ISSUE_LINKS:
    with open(link_file) as f:
        data = json.load(f)
        print(f"Read {len(data)} links from {link_file}")
        links += data
links = set(links)
print(f"Total {len(links)} unique links")
# Out:
# Read 1000 links from ./scrape_data/github_issues_(logs.px4.io).json
# Read 1000 links from ./scrape_data/github_issues_(review.px4.io).json
# Total 1808 unique links

# %%
px4_links = {}
for link in links:
    # Go through each issue page and scrape px4 URLs
    data = scrape_px4_links(link, True)
    px4_links[link] = {'count': len(data), 'log_links': data}
    
# Write to file
if len(px4_links) > 0:
    with open(f"{OUTPUT_ROOT}/px4_log_links.json", "w") as fp:
        json.dump(px4_links, fp)
# Out:
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/9414
# Found 126 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/12323
# Found 94 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/13779
# Found 309 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/13173
# Found 217 links on page and scraped 19 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/10175
# Found 326 links on page and scraped 13 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/15686
# Found 214 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/8151
# Found 117 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/11571
# Found 333 links on page and scraped 0 px4 log links!
#
# Zero links found, waiting to retry again
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/11571
# Found 333 links on page and scraped 0 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/10102
# Found 125 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/10139
# Found 201 links on page and scraped 8 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/11762
# Found 155 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/10738
# Found 254 links on page and scraped 5 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/9050
# Found 352 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/17385
# Found 123 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/11141
# Found 134 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/12195
# Found 140 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/12187
# Found 144 links on page and scraped 0 px4 log links!
#
# Zero links found, waiting to retry again
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/12187
# Found 144 links on page and scraped 0 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/11261
# Found 341 links on page and scraped 0 px4 log links!
#
# Zero links found, waiting to retry again
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/11261
# Found 341 links on page and scraped 0 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/13272
# Found 166 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/7719
# Found 109 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/17855
# Found 113 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/13751
# Found 132 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/10467
# Found 98 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/9206
# Found 165 links on page and scraped 13 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/13482
# Found 100 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/20315
# Found 114 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/13324
# Found 206 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/8497
# Found 309 links on page and scraped 4 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/9353
# Found 121 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/11308
# Found 386 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/12311
# Found 140 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/12650
# Found 316 links on page and scraped 10 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/8053
# Found 139 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/18544
# Found 235 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/16632
# Found 177 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/20275
# Found 162 links on page and scraped 5 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/17729
# Found 177 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/12158
# Found 157 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/11604
# Found 227 links on page and scraped 5 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/9723
# Found 158 links on page and scraped 4 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/8412
# Found 157 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/10991
# Found 134 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/19808
# Found 112 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/11222
# Found 114 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/9790
# Found 138 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/15450
# Found 114 links on page and scraped 5 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/18185
# Found 92 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/10812
# Found 122 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/7237
# Found 100 links on page and scraped 0 px4 log links!
#
# Zero links found, waiting to retry again
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/7237
# Found 100 links on page and scraped 0 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/18327
# Found 230 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/15673
# Found 141 links on page and scraped 4 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/7744
# Found 352 links on page and scraped 8 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/10035
# Found 149 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/10298
# Found 119 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/8496
# Found 177 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/20208
# Found 119 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/18271
# Found 146 links on page and scraped 4 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/7713
# Found 110 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/14479
# Found 144 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/17372
# Found 109 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/18491
# Found 341 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/15303
# Found 275 links on page and scraped 10 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/9918
# Found 168 links on page and scraped 18 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/9310
# Found 468 links on page and scraped 9 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/16335
# Found 124 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/15464
# Found 130 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/18919
# Found 151 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/10296
# Found 146 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/14099
# Found 356 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/11905
# Found 168 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/15865
# Found 236 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/10872
# Found 199 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/18437
# Found 119 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/14531
# Found 170 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/17769
# Found 124 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/8408
# Found 107 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/10785
# Found 490 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/9034
# Found 152 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/19268
# Found 120 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/18983
# Found 112 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/16744
# Found 262 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/16362
# Found 400 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/15746
# Found 109 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/17827
# Found 176 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/16444
# Found 335 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/13561
# Found 231 links on page and scraped 4 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/7260
# Found 163 links on page and scraped 7 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/20248
# Found 3 links on page and scraped 0 px4 log links!
#
# Zero links found, waiting to retry again
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/20248
# Found 139 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/10057
# Found 107 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/8531
# Found 121 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/14992
# Found 155 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/13422
# Found 101 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/9150
# Found 163 links on page and scraped 4 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/12030
# Found 106 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/15022
# Found 94 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/11824
# Found 121 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/15224
# Found 147 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/12180
# Found 105 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/12209
# Found 356 links on page and scraped 6 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/11032
# Found 163 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/12728
# Found 161 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/15775
# Found 153 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/8730
# Found 211 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/19223
# Found 112 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/7609
# Found 186 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/8915
# Found 191 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/13241
# Found 214 links on page and scraped 4 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/11487
# Found 200 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/8551
# Found 346 links on page and scraped 5 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/13346
# Found 258 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/12079
# Found 218 links on page and scraped 7 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/13355
# Found 109 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/7136
# Found 174 links on page and scraped 0 px4 log links!
#
# Zero links found, waiting to retry again
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/7136
# Found 174 links on page and scraped 0 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/19350
# Found 104 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/14127
# Found 208 links on page and scraped 7 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/10768
# Found 358 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/8130
# Found 108 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/7916
# Found 116 links on page and scraped 5 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/19342
# Found 264 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/14906
# Found 389 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/16391
# Found 134 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/11240
# Found 111 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/20415
# Found 113 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/11639
# Found 186 links on page and scraped 6 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/8102
# Found 178 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/15627
# Found 185 links on page and scraped 9 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/13663
# Found 122 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/7287
# Found 244 links on page and scraped 4 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/20350
# Found 141 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/7722
# Found 214 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/20056
# Found 216 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/12320
# Found 147 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/13596
# Found 271 links on page and scraped 20 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/18672
# Found 158 links on page and scraped 0 px4 log links!
#
# Zero links found, waiting to retry again
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/18672
# Found 158 links on page and scraped 0 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/15347
# Found 254 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/10817
# Found 109 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/12894
# Found 163 links on page and scraped 4 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/8392
# Found 175 links on page and scraped 11 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/15820
# Found 334 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/14367
# Found 145 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/9977
# Found 161 links on page and scraped 8 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/8842
# Found 114 links on page and scraped 4 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/8553
# Found 215 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/12908
# Found 157 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/14944
# Found 211 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/11144
# Found 211 links on page and scraped 8 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/17944
# Found 172 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/9023
# Found 183 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/15212
# Found 123 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/10420
# Found 126 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/17480
# Found 139 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/14062
# Found 240 links on page and scraped 6 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/17593
# Found 129 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/14749
# Found 194 links on page and scraped 5 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/8206
# Found 158 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/20367
# Found 123 links on page and scraped 6 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/7807
# Found 98 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/9831
# Found 112 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/12670
# Found 123 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/8997
# Found 116 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/10951
# Found 110 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/14781
# Found 134 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/18039
# Found 128 links on page and scraped 4 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/11700
# Found 112 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/11576
# Found 198 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/11896
# Found 397 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/9471
# Found 346 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/16873
# Found 160 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/15237
# Found 139 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/10840
# Found 131 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/12630
# Found 239 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/17558
# Found 135 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/19224
# Found 100 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/7932
# Found 274 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/7575
# Found 192 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/19448
# Found 94 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/11270
# Found 212 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/13060
# Found 186 links on page and scraped 4 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/15790
# Found 135 links on page and scraped 4 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/14875
# Found 181 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/9898
# Found 297 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/11748
# Found 96 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/19304
# Found 117 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/7490
# Found 194 links on page and scraped 5 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/15564
# Found 112 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/12348
# Found 299 links on page and scraped 18 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/16013
# Found 206 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/12806
# Found 283 links on page and scraped 6 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/18776
# Found 367 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/10807
# Found 111 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/13427
# Found 183 links on page and scraped 4 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/8751
# Found 140 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/14158
# Found 149 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/7651
# Found 3 links on page and scraped 0 px4 log links!
#
# Zero links found, waiting to retry again
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/7651
# Found 162 links on page and scraped 4 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/20357
# Found 195 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/11767
# Found 208 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/12950
# Found 186 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/16100
# Found 172 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/8165
# Found 220 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/18850
# Found 140 links on page and scraped 8 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/12353
# Found 379 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/9973
# Found 242 links on page and scraped 12 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/10116
# Found 361 links on page and scraped 7 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/7784
# Found 145 links on page and scraped 4 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/19912
# Found 355 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/15155
# Found 212 links on page and scraped 10 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/14891
# Found 110 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/17961
# Found 124 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/12984
# Found 336 links on page and scraped 5 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/13435
# Found 223 links on page and scraped 4 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/12152
# Found 106 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/10651
# Found 134 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/12294
# Found 107 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/20288
# Found 140 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/7746
# Found 158 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/13992
# Found 200 links on page and scraped 6 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/11013
# Found 351 links on page and scraped 11 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/13167
# Found 153 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/7194
# Found 167 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/12154
# Found 188 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/8913
# Found 289 links on page and scraped 6 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/8067
# Found 146 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/20573
# Found 147 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/18317
# Found 277 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/17695
# Found 156 links on page and scraped 4 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/12428
# Found 317 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/13536
# Found 214 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/9072
# Found 109 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/11987
# Found 138 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/15661
# Found 111 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/9295
# Found 101 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/17571
# Found 138 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/13244
# Found 128 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/14677
# Found 187 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/18591
# Found 343 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/16417
# Found 319 links on page and scraped 0 px4 log links!
#
# Zero links found, waiting to retry again
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/16417
# Found 319 links on page and scraped 0 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/13405
# Found 109 links on page and scraped 0 px4 log links!
#
# Zero links found, waiting to retry again
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/13405
# Found 109 links on page and scraped 0 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/10258
# Found 174 links on page and scraped 7 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/13691
# Found 129 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/16114
# Found 124 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/10928
# Found 205 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/16918
# Found 142 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/17485
# Found 277 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/20027
# Found 156 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/11677
# Found 121 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/17424
# Found 106 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/19539
# Found 235 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/19294
# Found 105 links on page and scraped 5 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/9730
# Found 162 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/12146
# Found 151 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/16048
# Found 121 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/16745
# Found 137 links on page and scraped 0 px4 log links!
#
# Zero links found, waiting to retry again
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/16745
# Found 137 links on page and scraped 0 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/11296
# Found 156 links on page and scraped 4 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/10731
# Found 101 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/16300
# Found 108 links on page and scraped 0 px4 log links!
#
# Zero links found, waiting to retry again
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/16300
# Found 108 links on page and scraped 0 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/13350
# Found 108 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/17199
# Found 116 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/15629
# Found 159 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/16593
# Found 115 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/16582
# Found 171 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/12696
# Found 364 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/10230
# Found 112 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/14602
# Found 158 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/14048
# Found 323 links on page and scraped 23 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/19774
# Found 170 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/11788
# Found 214 links on page and scraped 4 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/19814
# Found 100 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/12465
# Found 129 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/8920
# Found 254 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/13039
# Found 212 links on page and scraped 12 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/15106
# Found 249 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/11856
# Found 157 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/18061
# Found 120 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/9583
# Found 125 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/18407
# Found 155 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/20545
# Found 171 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/12954
# Found 165 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/7823
# Found 91 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/11071
# Found 149 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/13938
# Found 123 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/7276
# Found 130 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/15087
# Found 97 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/20486
# Found 128 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/8105
# Found 290 links on page and scraped 7 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/12804
# Found 131 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/9203
# Found 96 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/8275
# Found 115 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/17055
# Found 89 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/19523
# Found 214 links on page and scraped 10 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/14659
# Found 195 links on page and scraped 5 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/8655
# Found 144 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/18906
# Found 109 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/8424
# Found 214 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/12082
# Found 166 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/13036
# Found 354 links on page and scraped 8 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/11759
# Found 168 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/14350
# Found 166 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/8299
# Found 124 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/20114
# Found 310 links on page and scraped 6 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/14926
# Found 141 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/10592
# Found 111 links on page and scraped 5 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/12479
# Found 273 links on page and scraped 4 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/13460
# Found 188 links on page and scraped 15 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/18575
# Found 109 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/19338
# Found 105 links on page and scraped 4 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/18692
# Found 287 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/9078
# Found 112 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/13083
# Found 195 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/8376
# Found 191 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/14889
# Found 109 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/10636
# Found 210 links on page and scraped 8 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/13707
# Found 109 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/10037
# Found 282 links on page and scraped 4 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/13310
# Found 155 links on page and scraped 9 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/12579
# Found 227 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/13560
# Found 232 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/12632
# Found 133 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/16414
# Found 121 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/17788
# Found 214 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/9515
# Found 114 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/7233
# Found 154 links on page and scraped 9 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/16489
# Found 138 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/16380
# Found 124 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/9984
# Found 153 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/7915
# Found 130 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/14068
# Found 152 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/9803
# Found 134 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/8295
# Found 133 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/14051
# Found 320 links on page and scraped 4 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/18175
# Found 144 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/11267
# Found 325 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/10621
# Found 284 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/11866
# Found 159 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/10414
# Found 234 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/13093
# Found 129 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/7281
# Found 133 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/9698
# Found 393 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/10003
# Found 242 links on page and scraped 16 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/11092
# Found 351 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/10417
# Found 104 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/16846
# Found 150 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/13745
# Found 192 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/14612
# Found 144 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/12417
# Found 241 links on page and scraped 18 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/7567
# Found 128 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/17325
# Found 118 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/11167
# Found 282 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/10659
# Found 157 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/15940
# Found 135 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/9490
# Found 145 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/12447
# Found 116 links on page and scraped 0 px4 log links!
#
# Zero links found, waiting to retry again
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/12447
# Found 116 links on page and scraped 0 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/7219
# Found 330 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/18350
# Found 134 links on page and scraped 4 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/11400
# Found 386 links on page and scraped 7 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/9098
# Found 221 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/11744
# Found 157 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/8348
# Found 141 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/7841
# Found 146 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/13446
# Found 271 links on page and scraped 4 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/7463
# Found 120 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/11505
# Found 183 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/20268
# Found 105 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/12406
# Found 101 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/19529
# Found 278 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/14788
# Found 135 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/7541
# Found 139 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/14643
# Found 320 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/13309
# Found 120 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/17428
# Found 99 links on page and scraped 4 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/10620
# Found 127 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/8003
# Found 414 links on page and scraped 7 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/9978
# Found 217 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/20317
# Found 153 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/15625
# Found 97 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/10172
# Found 195 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/11837
# Found 222 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/13246
# Found 137 links on page and scraped 1 px4 log links!
#
# ...
# Found 108 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/13383
# Found 204 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/10879
# Found 192 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/10630
# Found 99 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/14847
# Found 134 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/19385
# Found 181 links on page and scraped 6 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/8600
# Found 146 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/17685
# Found 153 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/16931
# Found 279 links on page and scraped 0 px4 log links!
#
# Zero links found, waiting to retry again
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/16931
# Found 279 links on page and scraped 0 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/7871
# Found 135 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/12439
# Found 213 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/15667
# Found 122 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/19600
# Found 120 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/12175
# Found 262 links on page and scraped 9 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/10544
# Found 101 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/14735
# Found 212 links on page and scraped 6 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/14017
# Found 305 links on page and scraped 6 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/17746
# Found 127 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/20160
# Found 125 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/16724
# Found 166 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/18493
# Found 101 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/10590
# Found 161 links on page and scraped 5 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/8844
# Found 118 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/11043
# Found 112 links on page and scraped 4 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/9852
# Found 289 links on page and scraped 6 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/9921
# Found 101 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/14737
# Found 202 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/11738
# Found 165 links on page and scraped 5 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/18151
# Found 127 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/15352
# Found 194 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/9180
# Found 98 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/14560
# Found 143 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/19957
# Found 211 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/9137
# Found 116 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/19952
# Found 111 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/20173
# Found 137 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/12936
# Found 183 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/19178
# Found 132 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/18145
# Found 292 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/16496
# Found 336 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/18192
# Found 128 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/8109
# Found 137 links on page and scraped 9 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/12251
# Found 256 links on page and scraped 6 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/13510
# Found 204 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/10345
# Found 154 links on page and scraped 6 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/15615
# Found 108 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/13954
# Found 126 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/14221
# Found 388 links on page and scraped 6 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/16057
# Found 193 links on page and scraped 4 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/14660
# Found 127 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/9521
# Found 124 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/18318
# Found 269 links on page and scraped 0 px4 log links!
#
# Zero links found, waiting to retry again
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/18318
# Found 269 links on page and scraped 0 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/11961
# Found 161 links on page and scraped 5 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/12854
# Found 375 links on page and scraped 8 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/10826
# Found 101 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/20108
# Found 309 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/8632
# Found 155 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/13294
# Found 300 links on page and scraped 16 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/11859
# Found 334 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/17430
# Found 110 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/11434
# Found 232 links on page and scraped 4 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/15037
# Found 149 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/13480
# Found 202 links on page and scraped 10 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/15509
# Found 207 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/14952
# Found 137 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/7587
# Found 293 links on page and scraped 7 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/12277
# Found 202 links on page and scraped 0 px4 log links!
#
# Zero links found, waiting to retry again
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/12277
# Found 202 links on page and scraped 0 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/14473
# Found 253 links on page and scraped 27 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/7434
# Found 298 links on page and scraped 4 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/11812
# Found 194 links on page and scraped 4 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/9858
# Found 192 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/15565
# Found 289 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/10850
# Found 122 links on page and scraped 4 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/18391
# Found 93 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/17777
# Found 114 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/17083
# Found 109 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/7566
# Found 134 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/14933
# Found 153 links on page and scraped 8 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/9917
# Found 154 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/17087
# Found 113 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/14551
# Found 334 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/18576
# Found 114 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/13271
# Found 106 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/11949
# Found 148 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/14580
# Found 187 links on page and scraped 6 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/20405
# Found 171 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/9022
# Found 154 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/9028
# Found 393 links on page and scraped 4 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/16052
# Found 217 links on page and scraped 5 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/9726
# Found 143 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/13710
# Found 204 links on page and scraped 5 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/10061
# Found 136 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/7467
# Found 135 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/9344
# Found 136 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/9789
# Found 103 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/11213
# Found 153 links on page and scraped 6 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/15563
# Found 198 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/16369
# Found 128 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/19755
# Found 337 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/13148
# Found 183 links on page and scraped 5 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/8384
# Found 201 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/18369
# Found 131 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/18257
# Found 125 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/15882
# Found 320 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/8932
# Found 118 links on page and scraped 4 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/8771
# Found 367 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/13837
# Found 272 links on page and scraped 28 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/8733
# Found 117 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/19998
# Found 147 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/13675
# Found 134 links on page and scraped 4 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/14096
# Found 302 links on page and scraped 7 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/19608
# Found 141 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/12505
# Found 325 links on page and scraped 17 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/12204
# Found 138 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/7773
# Found 336 links on page and scraped 12 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/9621
# Found 153 links on page and scraped 8 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/12484
# Found 176 links on page and scraped 5 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/14857
# Found 122 links on page and scraped 3 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/9194
# Found 94 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/13526
# Found 282 links on page and scraped 4 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/7641
# Found 158 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/12441
# Found 153 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/14743
# Found 226 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/10986
# Found 288 links on page and scraped 8 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/pull/7346
# Found 294 links on page and scraped 2 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/7535
# Found 145 links on page and scraped 1 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/9761
# Found 133 links on page and scraped 9 px4 log links!
#
# Starting to scrape https://github.com/PX4/PX4-Autopilot/issues/8148
# Found 118 links on page and scraped 1 px4 log links!
